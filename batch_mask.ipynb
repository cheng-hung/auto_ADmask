# %%
import numpy as np
import matplotlib.pyplot as plt
from generate_basic_mask import DetectorMaskGenerator
import os, glob

# %%
# %matplotlib widget

# %%
tiff_dir = '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img'
baseline_mask_fn = '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/Mask_In_situ_coin_cell_holder3_20260330-174323_1c8064_sub.npy'
output_mask_dir = '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/auto_mask'

tiff_list = glob.glob(os.path.join(tiff_dir, '*.tiff'))
tiff_list.sort()

# %%
tiff_list
# Out:
# ['/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-133915_9eb0d5_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-150054_b2f26c_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-153309_6f6535_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-160606_86b53d_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-163856_e186ef_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-171111_f6d601_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-174323_1c8064_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-181548_6a25ea_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-184800_067f63_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-192014_d6ee6b_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-195226_a0d041_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-202438_105d87_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-205649_36552c_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-212904_3f7e95_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-220115_f97c10_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-223327_df6a56_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-230538_5e7cc8_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260330-233750_e1ed44_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-001002_289cbf_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-004217_df00c8_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-011429_05fcec_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-014640_8dcac1_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-021852_fbb090_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-025103_718375_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-032315_e73e70_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-035527_86e413_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-042739_30c6e4_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-045951_c59eb4_sub.tiff',
#  '/nsls2/users/clin1/Desktop/In_situ_coin_cell_holder3/pe1/img/In_situ_coin_cell_holder3_20260331-053202_ea9d03_sub.tiff']

# %%
# tn = os.path.basename(tiff_list[0])
# tn.split('.')[0]+'.npy'

# %%
for tiff in tiff_list[:]:
    base_name = os.path.basename(tiff)
    tiff_name = base_name.split('.')[0]
    gen = DetectorMaskGenerator(
        tiff,
        baseline_mask_npy=baseline_mask_fn,  # optional
        use_median_filter=True, 
        frame = 0, 
        median_window = 3, 
        median_tile_rows = 64, 
        zscore_window = 7,
        zscore_tile_rows = 256, 
        log_low_percentile = 10.0,
        log_high_percentile = 100.0,
        dead_z = -5.0,
        hot_z = 500000.0,
        sigma_floor_percentile = 5,
        beamstop = "off",
        # beamstop_low_percentile = 3.0,
        # beamstop_search_half_width = 120,
        # beamstop_max_anchor_distance = 50,
        # beamstop_min_run_width = 3,
        # beamstop_max_run_width = 80,
        # beamstop_padding = 8,
        # beamstop_tip_radius_x = 24,
        # beamstop_tip_radius_y = 32,
        use_radial_detector=True,
        center_y=998.8010441120437,
        center_x=1016.9889127734218,
        radial_sigma_floor_percentile=5.0, 
        radial_profile_exclude_masked=True, 
        radial_bin_width=0.5,
        radial_min_bin_pixels=10, 
        radial_hot_z=3.5,
        radial_component_min_pixels=1, 
        radial_component_max_pixels=400,
        radial_component_max_width=20,
        radial_component_max_height=20, 
        radial_component_max_aspect_ratio=100,
        border = 10,
        dilate = 0, 
    )
    
    mask = gen.generate_mask()
    output_mask_fn = os.path.join(output_mask_dir, tiff_name+'.npy')
    gen.save_mask_npy(output_mask_fn)

# %%
# params

# %%
plt.close('all')

# %%
f1, ax1 = plt.subplots(2, 3, figsize = (12, 9), constrained_layout=True)
ax1[0,0].imshow(mask)
ax1[0,1].imshow(gen.hot_mask)
ax1[0,2].imshow(gen.dead_mask)
ax1[1,0].imshow(gen.radial_mask)
ax1[1,1].imshow(gen.radial_zscore)
ax1[1,2].imshow(gen.local_zscore, vmin=-0.2, vmax=4.5)

plt.show()

# %%
gen.parameters
