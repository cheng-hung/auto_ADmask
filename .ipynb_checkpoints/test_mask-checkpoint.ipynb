# %%
import numpy as np
import matplotlib.pyplot as plt
from generate_basic_mask import DetectorMaskGenerator

# %%
# %matplotlib widget

# %%
tiff_fn = 'Cu2O_liquid_pdf_20260314-140254_db261a_primary.tiff'
mask_fn = 'Cu2O_liquid_pdf_20260314-140254_db261a_primary-chl.npy'

# %%
gen = DetectorMaskGenerator(
    tiff_fn,
    baseline_mask_npy=mask_fn,  # optional
    beamstop="off",
    border=10,
)

mask = gen.generate_mask(dead_z=-10, hot_z=10)
gen.save_mask_npy("output_mask.npy")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 gen = DetectorMaskGenerator(
#       2     tiff_fn,
#       3     baseline_mask_npy=mask_fn,  # optional
#       4     beamstop="off",
#
# TypeError: DetectorMaskGenerator.__init__() missing 1 required positional argument: 'basic_mask_npy'

# %%
generator.median_filter_tiled()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 generator.median_filter_tiled()
#
# TypeError: DetectorMaskGenerator.median_filter_tiled() missing 3 required positional arguments: 'array', 'window', and 'tile_rows'

# %%
plt.figure()
plt.imshow(mask)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
